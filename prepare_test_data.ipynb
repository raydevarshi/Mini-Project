# %%
import numpy as np

# Load the original dataset
X = np.load("/content/drive/MyDrive/mini project/X.npy")
y = np.load("/content/drive/MyDrive/mini project/y.npy")

# Train-Test Split (same logic as in training)
split = int(0.8 * len(X))
X_test = X[split:]
y_test = y[split:]

# Save test data
np.save("/content/drive/MyDrive/mini project/X_test.npy", X_test)
np.save("/content/drive/MyDrive/mini project/y_test.npy", y_test)

print("Test data prepared successfully!")
# Out:
# Test data prepared successfully!
